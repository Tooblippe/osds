# %%
from os import chdir
chdir('/home/osds')
# %run talktools
import socket
s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
s.connect(("gmail.com",80))
ip = s.getsockname()[0]
s.close()
# Out:
# <style>
# /*
#    Simple CSS styling for using IPython Notebooks for talks.
#
#    Author: Fernando Perez <fernando.perez@berkeley.edu>
# */
#
# .talk-title
# {
#   color: #498AF3;
#   font-size: 220%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 10px 50px 10px;
#   }
#
# .talk-subtitle
# {
#   color: #386BBC;
#   font-size: 150%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   }
#
# .slide-header, p.slide-header
# {
#   color: #498AF3;
#   font-size: 180%;
#   font-weight:bold;
#   margin: 0px 20px 10px;
#   page-break-before: always;
#   text-align: center;
#   }
#
# .rendered_html
# {
#   color: #2C5494;
#   font-family: Ubuntu;
#   font-size: 170%;
#   line-height: 1.1;
#   margin: 0.5em 0;
#   }
#
# .rendered_html h1
# {
#   color: #498AF3;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .rendered_html h2
# {
#   color: #386BBC;
#   line-height: 1.2;
# ...

# %%
s1 = 'http://%s/filemanager/filemanager/dialog.php' % ip
s2 = 'http://%s:57575/' % ip

# %%
website(s2)
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://188.226.182.138:57575/">http://188.226.182.138:57575/</a>
# </div>
# <iframe src="http://188.226.182.138:57575/"  width="800" height="450"></iframe>

# %%
website(s1)
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://188.226.182.138/filemanager/filemanager/dialog.php">http://188.226.182.138/filemanager/filemanager/dialog.php</a>
# </div>
# <iframe src="http://188.226.182.138/filemanager/filemanager/dialog.php"  width="800" height="450"></iframe>
